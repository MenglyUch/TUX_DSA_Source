# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("stores_new.csv")
df
# Out:
#    StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0     STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1     STR102      Apparel Zone       Apparel    Delhi           21.0
# 2     STR103       Super Bazar  Super Market    Delhi           22.8
# 3     STR104      Super Market  Super Market    Delhi           21.4
# 4     STR105     Central Store  Super Market    Delhi           18.7
# 5     STR106      Apparel Zone       Apparel    Delhi           18.1
# 6     STR107     Fashion Bazar       Apparel    Delhi           14.3
# 7     STR108     Digital Bazar  Electronincs    Delhi           24.4
# 8     STR109  Electronics Zone  Electronincs  Chennai           22.8
# 9     STR110      Apparel Zone       Apparel  Chennai           19.2
# 10    STR111       Super Bazar  Super Market  Chennai           17.8
# 11    STR112      Super Market  Super Market  Chennai           16.4
# 12    STR113     Central Store  Super Market  Chennai           17.3
# ...

# %% [raw]
# Data Inspection : Check columns that missing value or check how many columns and row

# %%
print(df.head())
# Out:
#   StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0    STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1    STR102      Apparel Zone       Apparel    Delhi           21.0
# 2    STR103       Super Bazar  Super Market    Delhi           22.8
# 3    STR104      Super Market  Super Market    Delhi           21.4
# 4    STR105     Central Store  Super Market    Delhi           18.7
#
#    Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 0         60       160.0              110            3.90       2.620
# 1         60       160.0              110            3.90       2.875
# 2         40       108.0               93            3.85       2.320
# 3         60       258.0              110            3.08       3.215
# 4         80       360.0              175            3.15       3.440
#
#    ProfitPercust  Dummy  OwnStore  OnlinePresence  Tenure  StoreSegment
# ...

# %%
print(df.tail())
# Out:
#    StoreCode      StoreName     StoreType Location  OperatingCost  Staff_Cnt  \
# 27    STR128   Super Market  Super Market  Kolkata           30.4         40
# 28    STR129  Central Store  Super Market  Kolkata           15.8         80
# 29    STR130   Apparel Zone       Apparel  Kolkata           19.7         60
# 30    STR131  Fashion Bazar       Apparel  Kolkata           15.0         80
# 31    STR132  Digital Bazar  Electronincs  Kolkata           21.4         40
#
#     TotalSales  Total_Customers  AcqCostPercust  BasketSize  ProfitPercust  \
# 27        95.1              113            3.77       1.513           16.9
# 28       351.0              264            4.22       3.170           14.5
# 29       145.0              175            3.62       2.770           15.5
# 30       301.0              335            3.54       3.570           14.6
# 31       121.0              109            4.11       2.780           18.6
#
# ...

# %%
print(df.shape)
# Out:
# (32, 16)

# %%
print(df.columns)
# Out:
# Index(['StoreCode', 'StoreName', 'StoreType', 'Location', 'OperatingCost',
#        'Staff_Cnt', 'TotalSales', 'Total_Customers', 'AcqCostPercust',
#        'BasketSize', 'ProfitPercust', 'Dummy', 'OwnStore', 'OnlinePresence',
#        'Tenure', 'StoreSegment'],
#       dtype='object')

# %%
df.describe()
# Out:
#        OperatingCost  Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  \
# count      32.000000  32.000000   32.000000        32.000000       29.000000
# mean       20.090625  61.875000  230.721875       146.687500        3.651034
# std         6.026948  17.859216  123.938694        68.562868        0.532664
# min        10.400000  40.000000   71.100000        52.000000        2.760000
# 25%        15.425000  40.000000  120.825000        96.500000        3.150000
# 50%        19.200000  60.000000  196.300000       123.000000        3.730000
# 75%        22.800000  80.000000  326.000000       180.000000        3.920000
# max        33.900000  80.000000  472.000000       335.000000        4.930000
#
#        BasketSize  ProfitPercust  Dummy   OwnStore  OnlinePresence     Tenure  \
# count   32.000000      32.000000    0.0  32.000000       32.000000  32.000000
# mean     3.217250      17.848750    NaN   0.437500        0.406250   3.687500
# ...

# %%
df.dtypes
# Out:
# StoreCode           object
# StoreName           object
# StoreType           object
# Location            object
# OperatingCost      float64
# Staff_Cnt            int64
# TotalSales         float64
# Total_Customers      int64
# AcqCostPercust     float64
# BasketSize         float64
# ProfitPercust      float64
# Dummy              float64
# OwnStore             int64
# OnlinePresence       int64
# Tenure               int64
# StoreSegment         int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   StoreCode        32 non-null     object
#  1   StoreName        32 non-null     object
#  2   StoreType        32 non-null     object
#  3   Location         32 non-null     object
#  4   OperatingCost    32 non-null     float64
#  5   Staff_Cnt        32 non-null     int64
#  6   TotalSales       32 non-null     float64
#  7   Total_Customers  32 non-null     int64
#  8   AcqCostPercust   29 non-null     float64
#  9   BasketSize       32 non-null     float64
#  10  ProfitPercust    32 non-null     float64
#  11  Dummy            0 non-null      float64
#  12  OwnStore         32 non-null     int64
#  13  OnlinePresence   32 non-null     int64
#  14  Tenure           32 non-null     int64
#  15  StoreSegment     32 non-null     int64
# dtypes: float64(6), int64(6), object(4)
# ...

# %%
df.count()
# Out:
# StoreCode          32
# StoreName          32
# StoreType          32
# Location           32
# OperatingCost      32
# Staff_Cnt          32
# TotalSales         32
# Total_Customers    32
# AcqCostPercust     29
# BasketSize         32
# ProfitPercust      32
# Dummy               0
# OwnStore           32
# OnlinePresence     32
# Tenure             32
# StoreSegment       32
# dtype: int64

# %%
df.value_counts('StoreCode')
# Out:
# StoreCode
# STR101    1
# STR102    1
# STR131    1
# STR130    1
# STR129    1
# STR128    1
# STR127    1
# STR126    1
# STR125    1
# STR124    1
# STR123    1
# STR122    1
# STR121    1
# STR120    1
# STR119    1
# STR118    1
# STR117    1
# STR116    1
# STR115    1
# STR114    1
# STR113    1
# STR112    1
# STR111    1
# STR110    1
# STR109    1
# STR108    1
# STR107    1
# STR106    1
# STR105    1
# STR104    1
# STR103    1
# STR132    1
# Name: count, dtype: int64

# %%
# Display with subset of columns
df.Location.unique()
# Out:
# array(['Delhi', 'Chennai', 'Mumbai', 'Kolkata'], dtype=object)

# %%
df[df.Location=='Mumbai']
# Out:
#    StoreCode         StoreName     StoreType Location  OperatingCost  \
# 16    STR117  Electronics Zone  Electronincs   Mumbai           14.7
# 17    STR118      Apparel Zone       Apparel   Mumbai           32.4
# 18    STR119       Super Bazar  Super Market   Mumbai           30.4
# 19    STR120      Super Market  Super Market   Mumbai           33.9
# 20    STR121     Central Store  Super Market   Mumbai           21.5
# 21    STR122      Apparel Zone       Apparel   Mumbai           15.5
# 22    STR123     Fashion Bazar       Apparel   Mumbai           15.2
# 23    STR124     Digital Bazar  Electronincs   Mumbai           13.3
#
#     Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 16         80       440.0              230            3.23       5.345
# 17         40        78.7               66            4.08       2.200
# 18         40        75.7               52            4.93       1.615
# ...

# %%
df[(df.TotalSales > 300) & (df.Location=='Delhi')]
# Out:
#   StoreCode      StoreName     StoreType Location  OperatingCost  Staff_Cnt  \
# 4    STR105  Central Store  Super Market    Delhi           18.7         80
# 6    STR107  Fashion Bazar       Apparel    Delhi           14.3         80
#
#    TotalSales  Total_Customers  AcqCostPercust  BasketSize  ProfitPercust  \
# 4       360.0              175            3.15        3.44          17.02
# 6       360.0              245            3.21        3.57          15.84
#
#    Dummy  OwnStore  OnlinePresence  Tenure  StoreSegment
# 4    NaN         0               0       3             2
# 6    NaN         0               0       3             4

# %%
df.loc[:,['OperatingCost', 'TotalSales','Total_Customers','AcqCostPercust']].head()
# Out:
#    OperatingCost  TotalSales  Total_Customers  AcqCostPercust
# 0           21.0       160.0              110            3.90
# 1           21.0       160.0              110            3.90
# 2           22.8       108.0               93            3.85
# 3           21.4       258.0              110            3.08
# 4           18.7       360.0              175            3.15

# %%
# Create columns total that .....
df['Total']= df['OperatingCost']+df['AcqCostPercust']*df['Total_Customers']
df.head()
# Out:
#   StoreCode         StoreName     StoreType Location  OperatingCost  \
# 0    STR101  Electronics Zone  Electronincs    Delhi           21.0
# 1    STR102      Apparel Zone       Apparel    Delhi           21.0
# 2    STR103       Super Bazar  Super Market    Delhi           22.8
# 3    STR104      Super Market  Super Market    Delhi           21.4
# 4    STR105     Central Store  Super Market    Delhi           18.7
#
#    Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  BasketSize  \
# 0         60       160.0              110            3.90       2.620
# 1         60       160.0              110            3.90       2.875
# 2         40       108.0               93            3.85       2.320
# 3         60       258.0              110            3.08       3.215
# 4         80       360.0              175            3.15       3.440
#
#    ProfitPercust  Dummy  OwnStore  OnlinePresence  Tenure  StoreSegment  \
# ...

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %%
df.isnull()
# Out:
#     StoreCode  StoreName  StoreType  Location  OperatingCost  Staff_Cnt  \
# 0       False      False      False     False          False      False
# 1       False      False      False     False          False      False
# 2       False      False      False     False          False      False
# 3       False      False      False     False          False      False
# 4       False      False      False     False          False      False
# 5       False      False      False     False          False      False
# 6       False      False      False     False          False      False
# 7       False      False      False     False          False      False
# 8       False      False      False     False          False      False
# 9       False      False      False     False          False      False
# 10      False      False      False     False          False      False
# 11      False      False      False     False          False      False
# ...

# %% [markdown]
# # Grouping and Aggregation

# %%
df.groupby(['Location','StoreType']).TotalSales.sum()
# Out:
# Location  StoreType
# Chennai   Apparel         915.4
#           Electronincs    600.8
#           Super Market    719.2
# Delhi     Apparel         745.0
#           Electronincs    306.7
#           Super Market    726.0
# Kolkata   Apparel         525.0
#           Electronincs    521.0
#           Super Market    566.4
# Mumbai    Apparel         700.7
#           Electronincs    790.0
#           Super Market    266.9
# Name: TotalSales, dtype: float64

# %%
# Out:
#   Cell In[32], line 1
#     df.to_sql(*)
#                ^
# SyntaxError: invalid syntax
